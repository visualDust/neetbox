# %%
from utils.logger import Logger, IconMode, ColorMode
from utils.image import ImageFolder

# %% [markdown]
# # Test Logger

# %%
logger0 = Logger(whom = __name__, ic = IconMode.sakura_filled, color = ColorMode.cyan).set_log_dir("./logdir")
logger1 = Logger(f"Tester{1}", IconMode.java,ColorMode.blue).bind_file("./for_debug.txt")
logger2 = Logger("logger0's shared log_file holder",ic=IconMode.setting,color=ColorMode.yellow).set_log_dir("./logdir")
logger0.log_os_info()
# Out:
# whom		|	visualdust using OffensiveQwQ
# machine		|	AMD64 on Intel64 Family 6 Model 151 Stepping 2, GenuineIntel
# system		|	Windows10.0.22624
# python		|	('default', 'Mar 25 2022 05:59:00'), ver 3.8.13

# %%
logger0.log("this message will be written to stdout and file")
logger0.log("this message will be written to stdout only", into_file=False)
logger0.log("this message will be written to file only", into_stdout=False)
logger0.log(
    "raw message without icon and datetime",
    with_datetime=False,
    with_ic=False,
    with_identifier=False,
)
logger2.log("I have the same log file as logger 0")
logger1.err("debug file only message")
# Out:
# 2023-03-05 14:50:32.751528 > ✿__main__ > this message will be written to stdout and file
# 2023-03-05 14:50:32.751528 > ✿__main__ > this message will be written to stdout only
# raw message without icon and datetime
# 2023-03-05 14:50:32.751528 > ⚙logger0's shared log_file holder > I have the same log file as logger 0
# [×]2023-03-05 14:50:32.752044 > ♨Tester > debug file only message

# %% [markdown]
# # Test ImageFolder

# %%
image_folder = ImageFolder(folder='./your_images_folder', sub_dirs= True, async_scan= False)
image_folder.get_image_list()
# Out:
# Folder Ready.
# ['./images\\jena_000018_000019_leftImg8bit.png',
#  './images\\jena_000019_000019_leftImg8bit.png',
#  './images\\b\\bremen_000001_000019_leftImg8bit.png',
#  './images\\b\\bremen_000010_000019_leftImg8bit.png',
#  './images\\a\\aachen_000000_000019_leftImg8bit.png',
#  './images\\a\\aachen_000001_000019_leftImg8bit.png']

# %%
image_folder.get_random_image()
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1024>
